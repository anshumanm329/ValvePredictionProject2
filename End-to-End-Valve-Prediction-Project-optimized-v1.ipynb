# %% [markdown]
# # Valve Position Prediction Project
# This project is aimed at using the behaviour of a `PID regulator` based control system obtained from `Matlab`
# to predict the opening level of the actuating mechanism (i.e. the valve) through various regressors such as `RandomForestRegressor` and `CatBoostRegressor`.
# ## 1. Problem definition
# > How well can a valve's position be predicted using the data obtained from a Matlab simulation of a PID based control system
# ## 2. Data
# > We have data from Matlab-Simulink based models of a PID based liquid level control system at `training_data_from_matlab2.csv/training_data_from_matlab3.csv etc`
# * The dataset has timestamps in `seconds` format.
# * It has the desired input levels of the liquid in meters.
# * The output liquid levels in meters as well
# * The feedback: The difference the desired output (input) and the actual output.
# * Opening levels of the valve in % (0-100)
#
# ### 2.1. How to format the data
# * We need to check what kind of format, the data under label `Time` are in and then convert them into either datetime.seconds or int64 format
# * Convert `string` datatypes to float using `pd.to_numeric(downcast = 'float')`
# * Eliminate any missing data by first generating `is_missing` boolean data for each column of the input data
# * Then eliminate by checking through `isna().sum()` and `_is_missing.value_counts()` and then eliminating the missing values by replacing them with `medians`
# * Eliminate erronious data. I.e. liquid levels above `1.0` in `input` and `liquid_level` columns and valve opening levels above `100` in `valve_positions` by replacing them with medians.
#
# > The data input and processing will be done using a function `preprocess_data(FILE_PATH)` fulfilling all the steps specified above.
# ## 3. Modelling
# * Use `train_test_split()` from `sklearn` to divide the dataset into training and validation datasets.
# * Use `RandomForestRegressor` to train the model using the training dataset.
# * Use `CatBoostRegressor` to train the model using the training dataset.
# * Use `RandomizedSearchCV` to get the optimize the model using the best hyperparameters `RandomForestRegressor`
# * Use `catboostcv` to obtain best hyperparameters for `CatBoostRegressor`
# * Evaluate the optimized model on the validation datasets.
# * Use test datasets to check the predictions of the model against true labels.
# ## 4. Saving the model for export and reuse
# At this step, we will save the model.
# * Use the `pickle` module to save the models
# * Or the `joblib` module to save the models.
#
# ## 5. Applying the output of the model on the transfer function of the control object
# * This purpose can be achieved using the `control` library.
# * Use the `control` library to simulate the output liquid level due to the valve opening levels predicted by the models in step 3

# %% [markdown]
# ## 2. Input and Preprocessing of data:
# Define a function named `preprocess_data(FILE_PATH)` which will take the liquid level control system modelling data obtained from simulations in MATLAB and preprocess the data into a format that can be used for modelling

# %% [markdown]
# ### Import the libraries

# %%
# Import the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import control as ct
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_squared_log_error, root_mean_squared_error, root_mean_squared_log_error
from catboost import CatBoostRegressor
import pickle
from joblib import load, dump
# %matplotlib inline

# %% [markdown]
# ### 2.1. Preparing the function to preprocess the data
# This function will:
# * Convert the data in the dataframe: presented in `string` format (`Time`) to numerical
# * Eliminate erroneous data (`Valve_Positions > 100`) and (`Liquid_levels > 1.5`)
# * Eliminate the missing values

# %%
#FILE_PATH = "training_data_from_matlab5.csv" or anything like that....

def preprocess_data(PROVIDED_FILE_PATH):
    """
    This function is meant to predict the opening level of a valve on the basis of input data, feedback data and timestamps
    The data is to be imported from the datasheets as specified in "FILE_PATH"
    The file will imported to a pandas dataframe
    The time data is to be converted from string to numeric
    A check will be performed to remove string type data, which is to be converted to float type
    Then a check will be performed for any missing data
    Then erroneous data (liquid levels > 1.2 and valve positions > 100) will be replaced with the median values of the respective columns
    The dataframe will be ready for further action!
    """
    # Step-1 read data from the file path
    print("Reading data....")
    df_data = pd.read_csv(PROVIDED_FILE_PATH)
    # Step-2 change the datatype of time column from string to numeric
    # In this case, we need to remove the phrase 'sec' from the column
    print("Changing the Time data from string to numeric....")
    df_data["Time"] = df_data["Time"].str.replace(" sec","",regex=True)
    # Then we will have to change the datatype from object to numeric
    df_data["Time"] = pd.to_numeric(df_data["Time"])
    # Step-3: Check for string type data
    print("Checking for string type data....")
    for label, content in df_data.items():
        if pd.api.types.is_string_dtype(content):
            print("There is string type data in: ",label)
            print("Converting strings to float in: ", label)
            df_data[label] = pd.to_numeric(df_data[label],errors = "coerce")
        else:
            print("There are no strings in: ", label)
    # Step-4: Check for missing data
    print("Checking for missing data....")
    for label, content in df_data.items():
        if pd.api.types.is_numeric_dtype(content):
            if pd.isnull(content).sum():
                print("There are missing values in: ", label)
                df_data[label + "is_missing"] = pd.isnull(content)
                # Now fill the missing data with zeroes
                df_data[label] = content.fillna(0)
            else:
                print("There are no missing values in: ",label)
    # Step-5: Now check for erroneous data
    print("Checking for erroneous data....")
    # In this case first we will be removing any values 
    for content in df_data["Liquid_levels"]:
        if (content > 1.5):
            print("Erroneous data found")
            content = df_data["Liquid_levels"].median()
    for content in df_data["Valve_Positions"]:
        if (content > 100.0):
            print("Erroneous data found")
            content = df_data["Valve_Positions"].median()


    
    print("Preprocessing complete....")
    print(df_data.info())
    return df_data

# %%
# Test the preprocessing data function
FILE_PATH = "training_data_from_matlab7.csv"
df_training_dataset1 = preprocess_data(FILE_PATH)
# Out:
# Reading data....
# Changing the Time data from string to numeric....
# Checking for string type data....
# There are no strings in:  Time
# There are no strings in:  Input
# There are no strings in:  Liquid_levels
# There are no strings in:  Feedback
# There are no strings in:  Valve_Positions
# Checking for missing data....
# There are no missing values in:  Time
# There are no missing values in:  Input
# There are no missing values in:  Liquid_levels
# There are no missing values in:  Feedback
# There are no missing values in:  Valve_Positions
# Checking for erroneous data....
# Preprocessing complete....
# <class 'pandas.DataFrame'>
# RangeIndex: 25474 entries, 0 to 25473
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Time             25474 non-null  float64
#  1   Input            25474 non-null  float64
#  2   Liquid_levels    25474 non-null  float64
# ...

# %% [markdown]
# ## 3. Modelling using RandomForestRegressor
# In this step, the data is to be modelled using `RandomForestRegressor`.
# Three steps are required to prepare and fit a model
# ### 3.1. Preparing the DataFrame for modelling
# A function to prepare the data for modelling by dividing it into features and labels dataframes;
#    * The function `prepare_for_modelling(DataFrame)` will take a DataFrame as input
#    * Drop the `Valve_Positions` column as the label (target variable)
#    * Use the other columns to set up the features dataframe (independent variables)

# %%
def prepare_for_modelling(DataFrame):
    """
    Function to prepare the data for fitting into the model
    Takes a dataframe as input. Drops the Valve_positions data for X and Valve_positions data is used as y
    X and y are returned
    """
    # If the number of columns in the input DataFrame is 2, i.e. one feature and the label then the feature dataframe has to be modified a bit
    # with pd.DataFrame(DataFrame.drop("Valve_Positions", axis = 1)
    if len(DataFrame.columns) >2:
        print("More than one feature")
        X = DataFrame.drop("Valve_Positions", axis = 1)
        y = DataFrame["Valve_Positions"]
        return X,y
    elif len(DataFrame.columns) == 2:
        print("One feature and the label")
        X = pd.DataFrame(DataFrame.drop("Valve_Positions", axis = 1))
        y = DataFrame["Valve_Positions"]
        return X,y
    else:
        print("Check the number of columns of the dataframe again")
        print(f"The number of columns: {len(DataFrame.columns)}" )
        return None

# %% [markdown]
# ### 3.2. Setup the dataframes for modelling

# %% [markdown]
# At this stage, dataframes are to be prepared with different features.
# 1. `df_training_data_2`: Contains all the features
# 2. `df_training_data_3`: Contains only the `Feedback` feature and `Valve_Positions` (labels)
# 3. `df_training_data_4`: Contains `Input`, `Liquid_levels` and `Feedback` features besides the labels
# 4. `df_training_data_5`: Contains the `Input` and `Feedback` features besides the labels
# 5. `df_training_data_6`: Contains the `Input` and `Liquid_levels` features besides the labels

# %%
# Dataframe with all features
df_training_data_2 = df_training_dataset1.copy()
#df_training_data_2.info()

# %%
# Dataframe with only Feedback and Valve_Positions
# df_training_data_3 = df_training_dataset1.drop(["Time", "Input", "Liquid_levels"], axis = 1)
#df_training_data_3.info()

# %%
# Dataframe with Input, Liquid_levels and Feedback
# df_training_data_4 = df_training_dataset1.drop("Time", axis=1)
#df_training_data_4.info()

# %%
# Dataframe with Input and Feedback 
# df_training_data_5 = df_training_dataset1.drop(["Time", "Liquid_levels"], axis = 1)
#df_training_data_5.info()

# %%
# Dataframe with Input and Liquid_levels
# df_training_data_6 = df_training_dataset1.drop(["Time", "Feedback"], axis = 1)
#df_training_data_6.info()

# %% [markdown]
# Create a function to create the modified dataframes named `create_modified_dataframe_from_original(DataFrame, dataframetype)`

# %%
def create_modified_dataframe(DataFrame, dataframetype):
    """
    A function to create modified dataframes from the input DataFrame containing data about the Liquid level control system,
    the variable "dataframetype"'s value determines what type of dataframe will be returned. 
    The prediction label 'Valve_Positions' is to remain in all dataframes since it will be removed during preparation for modelling
    dataframetype = 1: Returns the dataframe with all columns
    dataframetype = 2: Returns the dataframe with only "Feedback" 
    dataframetype = 3: Returns the dataframe with "Input", "Liquid_levels" and "Feedback" 
    dataframetype = 4: Returns the dataframe with "Input" and "Feedback"
    dataframetype = 5: Returns the dataframe with "Input" and "Liquid_levels"
    """
    print("Creating modified dataframe")
    match dataframetype:
        case 1:
            print("Dataframe with all the features")
            df_training_data = DataFrame.copy()
            return df_training_data
        case 2: 
            print("Dataframe with only Feedback feature and label")
            df_training_data = DataFrame.drop(["Time", "Input", "Liquid_levels"], axis = 1)
            return df_training_data
        case 3:
            print("Dataframe with Input, Liquid_levels and Feedback features apart from label")
            df_training_data = DataFrame.drop("Time", axis=1)
            return df_training_data
        case 4: 
            print("Dataframe with Input and Feedback features as well as label")
            df_training_data = DataFrame.drop(["Time", "Liquid_levels"], axis = 1)
            return df_training_data
        case 5: 
            print("Dataframe with Input and Liquid_levels features as well as label")
            df_training_data = DataFrame.drop(["Time", "Feedback"], axis = 1)
            return df_training_data
        case _:
            print("Invalid input, try using only numbers between 1 and 5")
            return None

# %%
df_training_data_1 = create_modified_dataframe(df_training_dataset1, 1)
df_training_data_2 = create_modified_dataframe(df_training_dataset1, 2)
df_training_data_3 = create_modified_dataframe(df_training_dataset1, 3)
df_training_data_4 = create_modified_dataframe(df_training_dataset1, 4)
df_training_data_5 = create_modified_dataframe(df_training_dataset1, 5)
# Out:
# Creating modified dataframe
# Dataframe with all the features
# Creating modified dataframe
# Dataframe with only Feedback feature and label
# Creating modified dataframe
# Dataframe with Input, Liquid_levels and Feedback features apart from label
# Creating modified dataframe
# Dataframe with Input and Feedback features as well as label
# Creating modified dataframe
# Dataframe with Input and Liquid_levels features as well as label

# %% [markdown]
# ### 3.3. Set up functions to create the required RandomForestRegressor model
#
# At this stage, `RandomForestRegressor` models are to be created.
# For this purpose, a user defined function `create_rf_model()` is to be created. The most important feature in the model is the `criterion` attribute of the `RandomForestRegressor`.
# The random seed in this case, i.e. `random_state` attribute of the regressor is to be set to 48 by default.
#
# The function `create_rf_model` will take in an attribute `metric` and set it against `criterion` of the RandomForestRegressor

# %%
def create_rf_model(metric):
    """
    Creates a RandomForestRegressor model with random_state = 48. 
    The value of metric set by the user will determine that criterion of the RFRegressor.
    The values of metric can be "absolute_error", "squared_error", "friedman_mse", "poisson" 
    If the user passes a value that doesn't belong to the above option, a model will be created with the default criterion i.e. "squared_error"
    """
    print("Creating RandomForestRegressor model")
    match metric:
        case "absolute_error":
            print("The metric is mean absolute error")
            model = RandomForestRegressor(criterion=metric,
                                          n_jobs = -1,
                                          random_state = 48)
            return model
        case "squared_error":
            print("The metric is mean squared error")
            model = RandomForestRegressor(criterion = metric,
                                          n_jobs = -1, 
                                          random_state = 48)
            return model
        case "friedman_mse":
            print("The metric is friedman_mse")
            model = RandomForestRegressor(criterion = metric,
                                          n_jobs = -1,
                                          random_state = 48)
            return model
        case "poisson":
            print("The metric is poisson")
            model = RandomForestRegressor(criterion = metric,
                                          n_jobs = -1,
                                          random_state = 48)
            return model
        case _:
            print("Invalid metric value, creating model with default metric")
            model = RandomForestRegressor(n_jobs = -1,
                                          random_state = 48)
            return model

# %%
# Create model_1 with squared error
# Create model_2 with absolute error
# Create model_3 with friedman mse
# Create model_4 with poisson
model_1 = create_rf_model("squared_error")
model_2 = create_rf_model("absolute_error")
model_3 = create_rf_model("friedman_mse")
model_4 = create_rf_model("poisson")
# Out:
# Creating RandomForestRegressor model
# The metric is mean squared error
# Creating RandomForestRegressor model
# The metric is mean absolute error
# Creating RandomForestRegressor model
# The metric is friedman_mse
# Creating RandomForestRegressor model
# The metric is poisson

# %% [markdown]
# ### 3.4. Separate the training labels and features and fit the training data
#
# Use the `prepare_for_modelling()` function to separate the features and labels
# and then fit the models

# %% [markdown]
# #### 3.4.1. Separate features and labels

# %%
# Separate features and labels from training data with all the features and label
X_train_1, y_train_1 = prepare_for_modelling(df_training_data_1)
# Out:
# More than one feature

# %%
# Separate features and labels from training data with just feedback and valve_positions
X_train_2, y_train_2 = prepare_for_modelling(df_training_data_2)
# Out:
# One feature and the label

# %%
# Separate features and labels from training data with features = Input, Liquid_levels, Feedback features
X_train_3, y_train_3 = prepare_for_modelling(df_training_data_3)
# Out:
# More than one feature

# %%
# Separate featues and labels from training data with Input, liquid levels features
X_train_4, y_train_4 = prepare_for_modelling(df_training_data_4)
# Out:
# More than one feature

# %%
# Separate features and labels from training data with Input, liquid_levels features
X_train_5, y_train_5 = prepare_for_modelling(df_training_data_5)
# Out:
# More than one feature

# %% [markdown]
# #### 3.4.2. Fit the data into the model

# %%
# %%time
model_2.fit(X_train_1, y_train_1)
# Out:
# CPU times: total: 33.3 s
# Wall time: 4.8 s
# RandomForestRegressor(criterion='absolute_error', n_jobs=-1, random_state=48)

# %%
# Create a copy of model_2
model_2_2 = create_rf_model("absolute_error")
model_2_2.fit(X_train_2, y_train_2)
# Out:
# Creating RandomForestRegressor model
# The metric is mean absolute error
# RandomForestRegressor(criterion='absolute_error', n_jobs=-1, random_state=48)

# %%
# Create a copy of model_2
model_2_3 = create_rf_model("absolute_error")
model_2_3.fit(X_train_3, y_train_3)
# Out:
# Creating RandomForestRegressor model
# The metric is mean absolute error
# RandomForestRegressor(criterion='absolute_error', n_jobs=-1, random_state=48)

# %%
# Create a copy of model_2
model_2_4 = create_rf_model("absolute_error")
model_2_4.fit(X_train_4, y_train_4)
# Out:
# Creating RandomForestRegressor model
# The metric is mean absolute error
# RandomForestRegressor(criterion='absolute_error', n_jobs=-1, random_state=48)

# %%
# Create a copy of model_2 
model_2_5 = create_rf_model("absolute_error")
model_2_5.fit(X_train_5, y_train_5)
# Out:
# Creating RandomForestRegressor model
# The metric is mean absolute error
# RandomForestRegressor(criterion='absolute_error', n_jobs=-1, random_state=48)

# %% [markdown]
# ## 4. Preparation of test data and evaluation of models
#
# The models have been trained
# The next stage is to utilize the same functions, in section 2 and 3 to prepare the test data and use the test data to evaluate the model

# %% [markdown]
# ### 4.1. Prepare the test data
#
# 1. Use the `preprocess_data()` function to import and preprocess the test dataframe
# 2. Use `create_modified_dataframe()` function to prepare the test data frame in various modified formats with different features
# 3. Use `prepare_for_modelling()` function to separate the features and labels of the test data
# 4. Evaluate the test data

# %%
# 1. Preprocess the data
TEST_DATA_PATH = "training_data_from_matlab5.csv"
df_test_dataset_1 = preprocess_data(TEST_DATA_PATH)
# Out:
# Reading data....
# Changing the Time data from string to numeric....
# Checking for string type data....
# There are no strings in:  Time
# There are no strings in:  Input
# There are no strings in:  Liquid_levels
# There are no strings in:  Feedback
# There are no strings in:  Valve_Positions
# Checking for missing data....
# There are no missing values in:  Time
# There are no missing values in:  Input
# There are no missing values in:  Liquid_levels
# There are no missing values in:  Feedback
# There are no missing values in:  Valve_Positions
# Checking for erroneous data....
# Preprocessing complete....
# <class 'pandas.DataFrame'>
# RangeIndex: 9021 entries, 0 to 9020
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Time             9021 non-null   float64
#  1   Input            9021 non-null   float64
#  2   Liquid_levels    9021 non-null   float64
# ...

# %%
# 2. Create the modified dataframes
df_test_data_1 = create_modified_dataframe(df_test_dataset_1, 1)
df_test_data_2 = create_modified_dataframe(df_test_dataset_1, 2)
df_test_data_3 = create_modified_dataframe(df_test_dataset_1, 3)
df_test_data_4 = create_modified_dataframe(df_test_dataset_1, 4)
df_test_data_5 = create_modified_dataframe(df_test_dataset_1, 5)
# Out:
# Creating modified dataframe
# Dataframe with all the features
# Creating modified dataframe
# Dataframe with only Feedback feature and label
# Creating modified dataframe
# Dataframe with Input, Liquid_levels and Feedback features apart from label
# Creating modified dataframe
# Dataframe with Input and Feedback features as well as label
# Creating modified dataframe
# Dataframe with Input and Liquid_levels features as well as label

# %%
# Prepare all the test datasets for modelling
X_test_1, y_test_1 = prepare_for_modelling(df_test_data_1)
X_test_2, y_test_2 = prepare_for_modelling(df_test_data_2)
X_test_3, y_test_3 = prepare_for_modelling(df_test_data_3)
X_test_4, y_test_4 = prepare_for_modelling(df_test_data_4)
X_test_5, y_test_5 = prepare_for_modelling(df_test_data_5)
# Out:
# More than one feature
# One feature and the label
# More than one feature
# More than one feature
# More than one feature

# %% [markdown]
# ### 4.2. Evaluate the predictions
# Have all the models created in section **3.4.2** predict on the test data and use `mean_absolute_error` function to get the mean absolute error

# %% [markdown]
# #### 4.2.1. Get the predicted labels

# %%
# Predict on X_test_1
y_preds_1 = model_2.predict(X_test_1)
# Predict on X_test_2
y_preds_2 = model_2_2.predict(X_test_2)
# Predict on X_test_3
y_preds_3 = model_2_3.predict(X_test_3)
# Predict on X_test_4
y_preds_4 = model_2_4.predict(X_test_4)
# Predict on X_test_5
y_preds_5 = model_2_5.predict(X_test_5)

# %% [markdown]
# #### 4.2.2. Create a function to get the evaluation results
# Create a function named `get_scores()` to get the evaluation metrics from various models
# The evaluation metrics will be:
# * `mean_absolute_error`
# * `mean_squared_error`
# * `root_mean_squared_error`
# * `r2_score`
# * `mean_squared_log_error`
# * `root_mean_squared_log_error`
# The input attributes to this function will be y_true and y_pred, which is the usual input values for any sklearn evaluation function

# %%
def get_scores(y_true, y_preds):
    """
    Takes the true labels and predicted labels as input. 
    Returns the mae, mse, r2_score, msle and rmsle as output
    """
    print(f"Mean absolute error: {mean_absolute_error(y_true, y_preds)}")
    print(f"Mean squared error: {mean_squared_error(y_true, y_preds)}")
    print(f"Root mean squared error: {root_mean_squared_error(y_true, y_preds)}")
    print(f"R2 score: {r2_score(y_true, y_preds)}")
    print(f"Mean squared log error: {mean_squared_log_error(y_true, y_preds)}")
    print(f"Root mean squared log error: {root_mean_squared_log_error(y_true, y_preds)}")

# %%
get_scores(y_test_1, y_preds_1)
# Out:
# Mean absolute error: 21.665341363098182
# Mean squared error: 475.2884933960698
# Root mean squared error: 21.80111220548323
# R2 score: -498.27164331167756
# Mean squared log error: 0.28790092392522837
# Root mean squared log error: 0.5365639979771549

# %%
get_scores(y_test_2, y_preds_2)
# Out:
# Mean absolute error: 9.305368268732895
# Mean squared error: 122.02447672836284
# Root mean squared error: 11.046468971049656
# R2 score: -127.18185558228592
# Mean squared log error: 0.06299318118305586
# Root mean squared log error: 0.250984424184163

# %%
get_scores(y_test_3, y_preds_3)
# Out:
# Mean absolute error: 21.807465714542225
# Mean squared error: 475.8185870520277
# Root mean squared error: 21.813266308648682
# R2 score: -498.82848559672453
# Mean squared log error: 0.28422524455103987
# Root mean squared log error: 0.5331277938271834

# %%
get_scores(y_test_4, y_preds_4)
# Out:
# Mean absolute error: 16.599232661406205
# Mean squared error: 275.71102708482533
# Root mean squared error: 16.60454838545226
# R2 score: -288.6234591925627
# Mean squared log error: 0.14281046003044776
# Root mean squared log error: 0.37790271238831796

# %%
get_scores(y_test_5, y_preds_5)
# Out:
# Mean absolute error: 27.162774082791596
# Mean squared error: 738.2507494458737
# Root mean squared error: 27.170770129789727
# R2 score: -774.5030260006012
# Mean squared log error: 0.5227167322276145
# Root mean squared log error: 0.7229915160135798

# %% [markdown]
# #### 4.2.3. Visualization
#
# * Create a function `plot_valve_pos()` to visualize the true labels and the predicted labels
# * Create a function `plot_liquid_levels()` to predict the predicted liquid levels

# %%
fig_size = (7.5, 6)
def plot_valve_pos(x, y_true, y_preds, fig_size):
    """
    Plots the predicted valve positions as well as the true valve positions against time
    """
    fig, ax = plt.subplots(figsize = fig_size)
    # Plot the true labels 
    ax.plot(x, y_true, c = "red", label = "True valve positions")
    # Plot the predicted labels
    ax.plot(x, y_preds, c = "blue", label = "Predicted valve positions")
    ax.set(xlabel = "Time (seconds)",
           ylabel = "Valve opening level (%)",
           title = "Valve positions predictions")
    ax.legend();

# %%
plot_valve_pos(X_test_1.Time, y_test_4, y_preds_4, fig_size = fig_size)

# %% [markdown]
# **Create the function to visualize the liquid levels**
#
# For this purpose, firstly a function to create the transfer function of the control object is required.

# %%
def create_transfer_function(nominal_level, valve_cross_section, tank_surface_area, valve_flow_coefficient = 1):
    """
    A function to create the transfer function of the control object of a liquid level control system
    Takes the nominal liquid level, valve cross-section and surface area of the tank containing
    the liquid as input
    """
    # Obtain the transfer coefficient K
    K = (2*nominal_level)/valve_cross_section
    # Obtain the time constant T
    T = (np.sqrt(2*nominal_level/9.8))*(tank_surface_area/(valve_flow_coefficient*valve_cross_section))
    # Obtain the transfer function
    W_object = ct.tf([K],[T,1])
    return W_object

# %%
W1 = create_transfer_function(0.8, 1.13, 36)
W1
# Out:
# TransferFunction(
# array([1.4159292]),
# array([12.87274039,  1.        ]),
# outputs=1, inputs=1)

# %% [markdown]
# **Create a function to visualize the predicted liquid level values, based on the predicted valve opening levels**
#
# We will require a time_vector and forced response from the transfer function

# %%
def plot_liquid_levels(W, df, y_true, y_preds, valve_area, fig_size = fig_size):
    """
    A function to plot the predicted liquid level values at the output of the function based on the predicted valve opening levels
    Valve cross-section is required here in order to simulate the regulating valve
    W: Transfer function of the control object
    df: Input dataframe
    """
    # Get a time_vector
    time_vector = np.linspace(0, len(df), df.Time.size)
    # Get the forced responses for the true liquid levels 
    time_returned_1, sysout = ct.forced_response(0.01*W, time_vector, y_true)
    time_returned_2, sysout2 = ct.forced_response(0.01*W, time_vector, y_preds)
    # Create the plots
    fig, ax = plt.subplots(figsize = fig_size)
    ax.plot(time_returned_1, sysout, c = "red", label = "True liquid levels")
    ax.plot(time_returned_2, sysout2, c = "blue", label = "Predicted liquid levels")
    ax.set(xlabel = "Time (seconds",
           ylabel = "Liquid level (m)",
           title = "Liquid level predictions")
    ax.legend();

# %%
# Test the function out
plot_liquid_levels(W = W1, df = df_test_dataset_1, y_true = y_test_1, y_preds = y_preds_1, valve_area = 1.13)
